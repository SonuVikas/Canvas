# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from matplotlib import image
from PIL import ImageDraw, ImageFont
from PIL import Image

# %%
netflixcanvas = Image.new(mode = 'RGB', size = (400, 300), color = (0,0,0))
netfWrite = ImageDraw.Draw(netflixcanvas)
font = ImageFont.truetype(r"C:\Users\Sonu Vikas\Desktop\AIMLDL\BebasNeue Bold.ttf", size = 100)
netfWrite.text((100, 100), text = 'NETFLIX',font = font, fill = (250, 9, 20))
plt.imshow(netflixcanvas)

# %%
ahaCanvas = Image.new(mode = 'RGB', size = (300, 200), color = (255,99,71))
ahaWrite = ImageDraw.Draw(ahaCanvas)
font = ImageFont.truetype(r"C:\Users\Sonu Vikas\Desktop\AIMLDL\MANDISA-Bold.ttf" , size = 100)
ahaWrite.text((80, 50), text = 'aha',font = font, fill = (255,255,255))
plt.imshow(ahaCanvas)

# %%
hotstarCanvas = Image.new(mode = 'RGB', size = (700, 300), color = (0, 0, 255))
hotstarWrite = ImageDraw.Draw(hotstarCanvas)
font = ImageFont.truetype(r"C:\Users\Sonu Vikas\Desktop\AIMLDL\waltograph42.ttf" , size = 100)
hotstarWrite.text((110, 100), text = 'Disney + hotstar',font = font, fill = (255,255,255))
plt.imshow(hotstarCanvas)

# %%
amazonCanvas = Image.new(mode = 'RGB', size = (1200, 350), color = (137, 207, 240))
amazonWrite = ImageDraw.Draw(amazonCanvas)
font = ImageFont.truetype(r"C:\Users\Sonu Vikas\Desktop\AIMLDL\Becham-Regular.otf" , size = 100)
amazonWrite.text((110, 100), text = 'amazon prime video',font = font, fill = (1, 1, 1))
plt.imshow(amazonCanvas)

# %%
vootCanvas = Image.new(mode = 'RGB', size = (400, 350), color = (93, 63, 211))
vootWrite = ImageDraw.Draw(vootCanvas)
font = ImageFont.truetype(r"C:\Users\Sonu Vikas\Desktop\AIMLDL\Becham-Regular.otf" , size = 100)
vootWrite.text((110, 100), text = 'voot',font = font, fill = (251,251,251))
plt.imshow(vootCanvas)

# %%
jioCanvas = Image.new(mode = 'RGB', size = (400, 350), color = (255, 49, 49))
jioWrite = ImageDraw.Draw(jioCanvas)
font = ImageFont.truetype(r"C:\Users\Sonu Vikas\Desktop\AIMLDL\MANDISA-Bold.ttf" , size = 100)
jioWrite.text((110, 100), text = 'Jio',font = font, fill = (251,251,251))
plt.imshow(jioCanvas)
